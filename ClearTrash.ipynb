# %%
# !pip install --upgrade --quiet google-api-python-client google-auth-httplib2 google-auth-oauthlib
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 20.6 MB/s eta 0:00:00

# %%
from google.colab import auth
from googleapiclient.discovery import build

# Authenticate and create the Drive API service
auth.authenticate_user()
from google.auth import default

creds, _ = default()
drive_service = build('drive', 'v3', credentials=creds)

# %%
def clear_trash():
    try:
        # List files in the trash
        results = drive_service.files().list(
            q="trashed=true",
            fields="nextPageToken, files(id, name)"
        ).execute()
        items = results.get('files', [])

        if not items:
            print('Trash is already empty.')
        else:
            for item in items:
                drive_service.files().delete(fileId=item['id']).execute()
                print(f"Deleted {item['name']} from trash.")
        print("Trash cleared.")
    except Exception as e:
        print(f"An error occurred: {e}")

# %%
import time

while True:
    clear_trash()
    time.sleep(120)  # Wait for 2 minutes before checking again
# Out:
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Deleted trainer_state.json from trash.
# Deleted rng_state.pth from trash.
# Deleted scheduler.pt from trash.
# Deleted training_args.bin from trash.
# Deleted preprocessor_config.json from trash.
# Deleted generation_config.json from trash.
# Deleted config.json from trash.
# Deleted checkpoint-400 from trash.
# Deleted trainer_state.json from trash.
# Deleted rng_state.pth from trash.
# Deleted scheduler.pt from trash.
# Deleted training_args.bin from trash.
# Deleted preprocessor_config.json from trash.
# Deleted generation_config.json from trash.
# Deleted config.json from trash.
# Deleted checkpoint-350 from trash.
# Deleted trainer_state.json from trash.
# Deleted rng_state.pth from trash.
# Deleted scheduler.pt from trash.
# Deleted training_args.bin from trash.
# Deleted preprocessor_config.json from trash.
# Deleted model.safetensors from trash.
# Deleted generation_config.json from trash.
# Deleted config.json from trash.
# Deleted checkpoint-250 from trash.
# Trash cleared.
# Deleted optimizer.pt from trash.
# Trash cleared.
# Deleted optimizer.pt from trash.
# Deleted model.safetensors from trash.
# Deleted optimizer.pt from trash.
# Deleted model.safetensors from trash.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# Trash is already empty.
# Trash cleared.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-4-9b10d4bbcaff> in <cell line: 3>()
#       3 while True:
#       4     clear_trash()
# ----> 5     time.sleep(120)  # Wait for 2 minutes before checking again
#
# KeyboardInterrupt:
